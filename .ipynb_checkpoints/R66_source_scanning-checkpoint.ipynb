# %% [markdown]
# # Finding the Maximum Flux
#
# In previous notebooks (N-MISC-17-003 pp 27-35) I have noted that the fluxes yielded by our K100 simulation at the two flux measurement points (called "low flux" and "high flux" locations) are discrepant.  The low flux point is typically lower in simulation by a factor of approximately 5 and the high flux point is higher in simulation by a factor of approximately 4.  This means that while [Matt and Nick's analysis][MandNflux] of the flux from Run 66 show about a factor of 100 between the low flux and high flux situations, the simulation shows a factor of nearly 1600.
#
# [MandNflux]: https://zzz.physics.umn.edu/cdms/doku.php?id=cdms:k100:run_summary:run_66:pube_activation#more_thorough_estimate_of_pube_activation_rates "new analysis of flux measurements in Run 66"
#
# Nevertheless, I have investigated the change of flux with small position variations in the source position.  The changes are displayed in the `R66_sim_position_shifting.ipynb` notebook in this directory and also referenced in N-MISC-17-003 pg 29.  Since those changes seem to vary sensibly we might hope that:
#
# >_even though the simulation does not match the measurements, the positional scaling will be "somewhat indicative" of the true flux scaling_.
#
# If that is the case then we can vary the position now and use the furthest position from the HV detector that keeps the flux reasonable to be a starting point for analyzing additional lead shielding to mitigate the gamma rate from having the source at that position.

# %% [markdown]
# ## Position Parameterization
#
# The basic idea is to use a position close to the high flux point and the low flux point as endpoints of a line along which to do several simulations of the source to see if there's a place that has a flux in the 1$\,$n/cm$^2$s range according to the simulation.  At that point we can try to vary the shielding to include a reasonable amount of lead near the source so that the NaI detector rate is reasonable.  We can also use the variation along the source line to form an intuitive picture for how the flux behaves.

# %%
import numpy as np

#first we need the endpoints -- label 'h' for high flux
xh = 0 #cm
yh = 33.02 #N-MISC-17-003 pg 29, #trelloP1
zh = 0 #should be near detector height
p_h = np.asarray([xh,yh,zh],dtype=np.float64)

#see the file templates/Run66Shield_stdLocation_inBarrel.mac.template for the standard position point--label
#'l' for low flux
xl = 0 #cm
yl = 119.731
zl = -64.679
p_l = np.asarray([xl,yl,zl],dtype=np.float64)

#get unit vector pointing from high flux to low flux
ltot = np.linalg.norm(p_l-p_h)
uvec = (p_l-p_h)/ltot

#chop up the region
N = 10
for i in np.arange(N+1):
    d = ltot/np.float(N)
    vec = p_h + i*d*uvec
    print(vec)
# Out:
# [  0.    33.02   0.  ]
# [  0.      41.6911  -6.4679]
# [  0.      50.3622 -12.9358]
# [  0.      59.0333 -19.4037]
# [  0.      67.7044 -25.8716]
# [  0.      76.3755 -32.3395]
# [  0.      85.0466 -38.8074]
# [  0.      93.7177 -45.2753]
# [   0.      102.3888  -51.7432]
# [   0.      111.0599  -58.2111]
# [   0.     119.731  -64.679]

# %% [markdown]
# ## Scanning the Source Position and Measuring Flux
#
# Now that the position of the source is parameterized, I have to run the K100 simulation with those different positions of the Pu/Be source and record the flux in the detector.  This is done below.  Note that here I am only measuring the effective thermal neutron flux at the detector and not the other two important parameters like the total rate in the detector and the total rate in the NaI coincidence detectors.

# %%
import scanData as sd

#a function to get three rows of data x y z
data = sd.getScanData('data/Run66Sim_FluxScan0.txt')
dataF1 = sd.getScanData('data/Run66Sim_FluxScan1.txt')
dataF2 = sd.getScanData('data/Run66Sim_FluxScan2.txt')
dataF3 = sd.getScanData('data/Run66Sim_FluxScan3.txt')




print(data['ey'])
print(data['eyl'])
print(data['eyu'])
# Out:
# [ 0.57669282  0.29472485  0.12145072  0.10019464  0.07189506  0.04763689
#   0.03969741  0.02100589  0.01775322  0.01247569]
# [ 0.57164268  0.29376082  0.11909223  0.09703811  0.07145534  0.04763689
#   0.03969741  0.02381845  0.01587896  0.00882165]
# [ 0.57164268  0.29376082  0.11909223  0.09703811  0.07145534  0.04763689
#   0.03969741  0.02381845  0.01587896  0.00882165]

# %%
#set up a plot 
import matplotlib as mpl
from matplotlib import pyplot as plt
#got smarter about the mpl config: see mplstyles/ directory
plt.style.use('standard')

# %%
#set up a plot
fig,axes = plt.subplots(1,1,figsize=(9.0,8.0))
ax1 = axes

#lay out the colors
rgb_r = (255/255.0,0/255.0,0/255.0)
rgb_b = (0/255.0,0/255.0,255/255.0)
rgb_o = (255/255.0,127/255.0,0/255.0)
rgb_b = (31/255.0,120/255.0,180/255.0)
rgb_lr = (251/255.0,154/255.0,153/255.0)
rgb_g = (203/255.0,195/255.0,195/255.0)

ax1.errorbar(data['xx'], data['yy'], yerr=[data['eyl'],data['eyu']],marker='o', markersize=8, \
             linestyle='none',color='k', label='R66 capture simulation')
ax1.errorbar(dataF1['xx'], dataF1['yy'], yerr=[dataF1['eyl'],dataF1['eyu']],marker='o', markersize=8, \
             linestyle='none',color='r', label='R66 w/o poly wall')
ax1.errorbar(dataF2['xx'], dataF2['yy'], yerr=[dataF2['eyl'],dataF2['eyu']],marker='o', markersize=8, \
             linestyle='none',color='b', label='- src. barrel')
ax1.errorbar(dataF3['xx'], dataF3['yy'], yerr=[dataF3['eyl'],dataF3['eyu']],marker='o', markersize=8, \
             linestyle='none',color='g', label='- East poly wall')
#ax1.errorbar(dataF7['xx'], dataF7['yy'], yerr=[dataF7['eyl'],dataF7['eyu']],marker='o', markersize=8, \
#             linestyle='none',color='C1', label='change to $^{3}$He bath')
#ax1.errorbar(dataV0['xx'], dataV0['yy'], yerr=dataV0['ey'],marker='o', markersize=8, linestyle='none',color='r', label='standard position')
#xx = np.arange(0,13,dx)


ax1.set_yscale('log')
ax1.set_xlim(30, 140)
ax1.set_ylim(1e-2,1000)
ax1.set_xlabel('radial displacement [cm]',**axis_font)
ax1.set_ylabel('flux [n/cm$^2$s]',**axis_font)
ax1.grid(True)
ax1.yaxis.grid(True,which='minor',linestyle='--')
ax1.legend(loc=1,prop={'size':22})

for axis in ['top','bottom','left','right']:
  ax1.spines[axis].set_linewidth(2)

plt.tight_layout()
plt.savefig('figures/R66_source_scan.png')
plt.show()

# %% [markdown]
# ## Adding Walls and Ceiling to Simulation Geometry
#
# The previous simulations did not include the (drywall) walls and (concrete) ceiling of the laboratory.  They are included now and we can compare the fluxes determined with these geometry changes.

# %%
#let's get the standard scan (Scan0 source positions) but with the updated geometry
dataF4 = sd.getScanData('data/Run66Sim_FluxScan4.txt')
dataF7 = sd.getScanData('data/Run66Sim_FluxScan7.txt')

#also get the experimental measurements of flux
import dataPython as dp
measF = dp.getXYdata_wYerr('data/Run66_Flux_measurements.txt')

# %%
#set up a plot
fig,axes = plt.subplots(1,1,figsize=(9.0,8.0))
ax1 = axes

#lay out the colors
rgb_r = (255/255.0,0/255.0,0/255.0)
rgb_b = (0/255.0,0/255.0,255/255.0)
rgb_o = (255/255.0,127/255.0,0/255.0)
rgb_b = (31/255.0,120/255.0,180/255.0)
rgb_lr = (251/255.0,154/255.0,153/255.0)
rgb_g = (203/255.0,195/255.0,195/255.0)

ax1.errorbar(data['xx'], data['yy'], yerr=[data['eyl'],data['eyu']],marker='o', markersize=8, \
             linestyle='none',color='k', label='R66 capture simulation')
ax1.errorbar(dataF4['xx'], dataF4['yy'], yerr=[dataF4['eyl'],dataF4['eyu']],marker='o', markersize=8, \
             linestyle='none',color='r', label='R66 sim w/ walls and ceiling')
ax1.errorbar(dataF7['xx'], dataF7['yy'], yerr=[dataF7['eyl'],dataF7['eyu']],marker='o', markersize=8, \
             linestyle='none',color='C1', label='change to $^{3}$He bath')
ax1.errorbar(measF['xx'], measF['yy'], yerr=measF['ey'],marker='o', markersize=8, \
             linestyle='none',color=rgb_b, label='R66 flux measurement')

#ax1.errorbar(dataV0['xx'], dataV0['yy'], yerr=dataV0['ey'],marker='o', markersize=8, linestyle='none',color='r', label='standard position')
#xx = np.arange(0,13,dx)


ax1.set_yscale('log')
ax1.set_xlim(30, 140)
ax1.set_ylim(1e-3,1000)
ax1.set_xlabel('radial displacement [cm]',**axis_font)
ax1.set_ylabel('flux [n/cm$^2$s]',**axis_font)
ax1.grid(True)
ax1.yaxis.grid(True,which='minor',linestyle='--')
ax1.legend(loc=1,prop={'size':22})

for axis in ['top','bottom','left','right']:
  ax1.spines[axis].set_linewidth(2)

plt.tight_layout()
plt.savefig('figures/R66_wall_compare.png')
plt.show()

# %% [markdown]
# ## Counting $^{70}$Ge Captures More Accurately

# %%
#let's get the standard scan (Scan0 source positions) but with the updated geometry AND only 70Ge captures
#input the total macroscopic cross section recalculate from N-MISC-17-001 pg 14 and Cap sigma 3.71 b
dataF4_70 = sd.getScanData('data/Run66Sim_FluxScan4_70Ge.txt',0.02899)

# %%
#set up a plot
fig,axes = plt.subplots(1,1,figsize=(9.0,8.0))
ax1 = axes


ax1.errorbar(dataF4_70['xx'], dataF4_70['yy'], yerr=[dataF4_70['eyl'],dataF4_70['eyu']],marker='o', markersize=8, \
             linestyle='none',color='r', label='R66 sim w/ walls and ceiling')
ax1.errorbar(measF['xx'], measF['yy'], yerr=measF['ey'],marker='o', markersize=8, \
             linestyle='none',color=rgb_b, label='R66 flux measurement')
#ax1.errorbar(dataV0['xx'], dataV0['yy'], yerr=dataV0['ey'],marker='o', markersize=8, linestyle='none',color='r', label='standard position')
#xx = np.arange(0,13,dx)


ax1.set_yscale('log')
ax1.set_xlim(30, 140)
ax1.set_ylim(1e-2,1000)
ax1.set_xlabel('radial displacement [cm]',**axis_font)
ax1.set_ylabel('flux [n/cm$^2$s]',**axis_font)
ax1.grid(True)
ax1.yaxis.grid(True,which='minor',linestyle='--')
ax1.legend(loc=1,prop={'size':22})

for axis in ['top','bottom','left','right']:
  ax1.spines[axis].set_linewidth(2)

plt.tight_layout()
#plt.savefig('figures/thefigure.png')
plt.show()

# %%
#Get Flux Scan 5 data--using a Poly reflector behind source barrel
dataF5_70 = sd.getScanData('data/Run66Sim_FluxScan5_70Ge.txt',0.02899)
dataF5 = sd.getScanData('data/Run66Sim_FluxScan5.txt')

# %%
#set up a plot
fig,axes = plt.subplots(1,1,figsize=(9.0,8.0))
ax1 = axes


ax1.errorbar(dataF4_70['xx'], dataF4_70['yy'], yerr=[dataF4_70['eyl'],dataF4_70['eyu']],marker='o', markersize=8, \
             linestyle='none',color='r', label='R66 sim w/ walls and ceiling')
ax1.errorbar(dataF5_70['xx'], dataF5_70['yy'], yerr=[dataF5_70['eyl'],dataF5_70['eyu']],marker='o', markersize=8, \
             linestyle='none',color='k', label='R66 sim w/ walls, ceiling, and west reflector')
ax1.errorbar(measF['xx'], measF['yy'], yerr=measF['ey'],marker='o', markersize=8, \
             linestyle='none',color=rgb_b, label='R66 flux measurement')
#ax1.errorbar(dataV0['xx'], dataV0['yy'], yerr=dataV0['ey'],marker='o', markersize=8, linestyle='none',color='r', label='standard position')
#xx = np.arange(0,13,dx)


ax1.set_yscale('log')
ax1.set_xlim(30, 140)
ax1.set_ylim(1e-2,1000)
ax1.set_xlabel('radial displacement [cm]',**axis_font)
ax1.set_ylabel('flux [n/cm$^2$s]',**axis_font)
ax1.grid(True)
ax1.yaxis.grid(True,which='minor',linestyle='--')
ax1.legend(loc=1,prop={'size':22})

for axis in ['top','bottom','left','right']:
  ax1.spines[axis].set_linewidth(2)

plt.tight_layout()
#plt.savefig('figures/thefigure.png')
plt.show()

# %% [markdown]
# ## Try to Put Source In Pit

# %%
#

#first we need the endpoints -- label 'h' for high flux
xh = 0 #cm
yh = 0
zh = -60 #should be below cryostat
p_h = np.asarray([xh,yh,zh],dtype=np.float64)

#see the file templates/Run66Shield_stdLocation_inBarrel.mac.template for the standard position point--label
#'l' for low flux
xl = 0 #cm
yl = 0
zl = -200
p_l = np.asarray([xl,yl,zl],dtype=np.float64)

#get unit vector pointing from high flux to low flux
ltot = np.linalg.norm(p_l-p_h)
uvec = (p_l-p_h)/ltot

#chop up the region
N = 10
for i in np.arange(N+1):
    d = ltot/np.float(N)
    vec = p_h + i*d*uvec
    print(vec)
# Out:
# [  0.   0. -60.]
# [  0.   0. -74.]
# [  0.   0. -88.]
# [   0.    0. -102.]
# [   0.    0. -116.]
# [   0.    0. -130.]
# [   0.    0. -144.]
# [   0.    0. -158.]
# [   0.    0. -172.]
# [   0.    0. -186.]
# [   0.    0. -200.]

# %%
#Get Flux Scan 6 data--using a Poly reflector in pit
dataF6_70 = sd.getScanData('data/Run66Sim_FluxScan6_70Ge.txt',0.02899)
dataF6 = sd.getScanData('data/Run66Sim_FluxScan6.txt')

# %%
#set up a plot
fig,axes = plt.subplots(1,1,figsize=(9.0,8.0))
ax1 = axes


ax1.errorbar(dataF4['xx'], dataF4['yy'], yerr=[dataF4['eyl'],dataF4['eyu']],marker='o', markersize=8, \
             linestyle='none',color='r', label='R66 sim w/ walls and ceiling')
ax1.errorbar(dataF6['xx'], dataF6['yy'], yerr=[dataF6['eyl'],dataF6['eyu']],marker='o', markersize=8, \
             linestyle='none',color='k', label='R66 sim w/ walls, ceiling, source in pit')
ax1.errorbar(measF['xx'], measF['yy'], yerr=measF['ey'],marker='o', markersize=8, \
             linestyle='none',color=rgb_b, label='R66 flux measurement')
#ax1.errorbar(dataV0['xx'], dataV0['yy'], yerr=dataV0['ey'],marker='o', markersize=8, linestyle='none',color='r', label='standard position')
#xx = np.arange(0,13,dx)


ax1.set_yscale('log')
ax1.set_xlim(30, 210)
ax1.set_ylim(1e-3,100)
ax1.set_xlabel('radial displacement [cm]',**axis_font)
ax1.set_ylabel('flux [n/cm$^2$s]',**axis_font)
ax1.grid(True)
ax1.yaxis.grid(True,which='minor',linestyle='--')
ax1.legend(loc=1,prop={'size':22})

for axis in ['top','bottom','left','right']:
  ax1.spines[axis].set_linewidth(2)

plt.tight_layout()
#plt.savefig('figures/thefigure.png')
plt.show()

# %%
#Get Full Rate data
dataR4 = sd.getScanData_wRates('data/Run66Sim_RateMeasure4.txt')
dataR4_alt = sd.getScanData_wRates('data/Run66Sim_FluxScan4_allRates.txt')

# %%
#set up a plot
fig,axes = plt.subplots(1,1,figsize=(9.0,8.0))
ax1 = axes


ax1.errorbar(dataR4['xx'], dataR4['zrate'], yerr=[dataR4['ezratel'],dataR4['ezrateu']],marker='o', markersize=8, \
             linestyle='none',color='r', label='HV detector')
ax1.errorbar(dataR4['xx'], dataR4['naibr'], yerr=[dataR4['enaibrl'],dataR4['enaibru']],marker='o', markersize=8, \
             linestyle='none',color='k', label='NaI detector B')
ax1.errorbar(dataR4['xx'], dataR4['naicr'], yerr=[dataR4['enaicrl'],dataR4['enaicru']],marker='o', markersize=8, \
             linestyle='none',color='b', label='NaI detector C')
#ax1.errorbar(dataR4_alt['xx'], dataR4_alt['zrate'], yerr=[dataR4_alt['ezratel'],dataR4_alt['ezrateu']],marker='^', markersize=8, \
#             linestyle='none',color='r', label='')
#ax1.errorbar(dataR4_alt['xx'], dataR4_alt['naibr'], yerr=[dataR4_alt['enaibrl'],dataR4_alt['enaibru']],marker='^', markersize=8, \
#             linestyle='none',color='k', label='')
#ax1.errorbar(dataR4_alt['xx'], dataR4_alt['naicr'], yerr=[dataR4_alt['enaicrl'],dataR4_alt['enaicru']],marker='^', markersize=8, \
#             linestyle='none',color='b', label='')
#ax1.errorbar(dataF6['xx'], dataF6['yy'], yerr=[dataF6['eyl'],dataF6['eyu']],marker='o', markersize=8, \
#             linestyle='none',color='k', label='R66 sim w/ walls, ceiling, source in pit')
#ax1.errorbar(measF['xx'], measF['yy'], yerr=measF['ey'],marker='o', markersize=8, \
#             linestyle='none',color=rgb_b, label='R66 flux measurement')
#ax1.errorbar(dataV0['xx'], dataV0['yy'], yerr=dataV0['ey'],marker='o', markersize=8, linestyle='none',color='r', label='standard position')
#xx = np.arange(0,13,dx)


ax1.set_yscale('log')
ax1.set_xlim(30, 140)
ax1.set_ylim(1e0,10000)
ax1.set_xlabel('radial displacement [cm]',**axis_font)
ax1.set_ylabel('rate [Hz]',**axis_font)
ax1.grid(True)
ax1.yaxis.grid(True,which='minor',linestyle='--')
ax1.legend(loc=3,prop={'size':22})

for axis in ['top','bottom','left','right']:
  ax1.spines[axis].set_linewidth(2)

plt.tight_layout()
#plt.savefig('figures/thefigure.png')
plt.show()
